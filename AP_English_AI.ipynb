# %% [markdown]
# <a href="https://colab.research.google.com/github/AndersonBlanco/CubePalsOfficials/blob/main/AP_English_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scipy gtts pyttsx3 nltk numpy TextBlob monkeyLearn tweepy
#

# %%
import gtts
from gtts import gTTS
from gtts import lang
import os

#text to speech
import pyttsx3
from IPython.display import Audio
import time
import nltk
from nltk import classify
from nltk import NaiveBayesClassifier
from nltk.corpus import twitter_samples

#for raw code sentiment analysis using python nltk library (FOR NLP) 
import nltk.classify.util
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import movie_reviews
from numpy import moveaxis

#for mokeyLearn
import monkeylearn
from monkeylearn import MonkeyLearn

#for textblob easy dioffuclty text sentiment analysis 
from textblob import TextBlob


#for twitter api
import tweepy
import textblob 
#from textBlob import TextBlob -- reason for commented out = "already doen previously" 
import pandas as pd
import re
import matplotlib.pyplot as plt
import numpy as np
from wordcloud import WordCloud
from google.colab import files


#graph
import scipy
from scipy.stats import linregress

# %%
#engine = pyttsx3.init()
#engine.say("Hey There")
#engine.runAndWait()
#nltk.download("punkt")

# %%
polarity,
from textblob.en import subjectivity
######################################################################################### sentiment analysis with a python library. Difficulty = easy with less control ###############################################################################

from textblob import TextBlob



positiveText = [
        'I love this sandwich.', 
       'this is an amazing place!', 
     'I feel very good about these beers.',
     'this is my best work.', 
     "what an awesome view", 

]

negativeText = [
     'I do not like this restaurant',
'I am tired of this stuff.', 'neg',
     "I can't deal with this",
     'he is my sworn enemy!', 'neg',
     'my boss is horrible.', 'neg'
]

#cl = textblob.classifiers.PositiveNaiveBayesClassifier(positiveText, negativeText)

testingText = [
         ('the beer was good.', 'pos'),
     ('I do not enjoy my job', 'neg'),
     ("I ain't feeling dandy today.", 'neg'),
     ("I feel amazing!", 'pos'),
('Gary is a friend of mine.', 'pos'),
     ("I can't believe I'm doing this.", 'neg')
]

#def Traing():
  #cl.classify("Have a good day")

#polarity = if opinion is pos or neg.  0.5 > = pos, 0.5 < = neg
def Analysis(text: str()) -> str():
  sentiments = []


  blob = TextBlob(text)

  typeOfOpionion = blob.subjectivity 
  if bool(blob.polarity) == True && bool(blob.polarity == ):
    return False, (blob.polarity)
  else:
    return True, (blob.polarity)

  


sampleText = "Humans are aweful beings. They are not good"

userText = input("Your opinion: ")

userSentiment = Analysis(userText)

print(Analysis(userText))

# %%
import random
# !from pandas.core.algorithms import mode
########Use MonkeyLearn(api key needed from their website service) sentiment analysis service with a python (you may create your own model and train it in MonkeyLearn dashboard website ). Difficulty = easy with more control  ###############################################################################


#name of model: SAM - Sentiment Analysis Model
#apiKey = "cc9f95c84d1dcd7408e840736fa460bc8a54dc27"
#modelID = "cl_3TKZmfsE"
#SAM = MonkeyLearn(apiKey)
sampleText = ["The Universe is awesome"] #########    Sample Text

#types of classifiers
#classifierss = SAM.classifiers.list(page = 2, per_page = 5, order_by=["-is_public", "name"])
##SAM_details = SAM.classifiers.detail(modelID)

print("Output: ", end = "\n\n")

#for models_OR_classifiers in classifierss.body:
  #print(models_OR_classifiers, "\n")

print(SAM_details.body)


#traning################
##hotelReviews = pd.read_csv("sample_data/hotelReviews.csv")
#trainingRes = SAM.classifiers.train()


#results ##################
#res = SAM.classifiers.classify(modelID, sampleText)
#bodyData = res.body
#sentimentTag = res.body[0]["classifications"][0]["tag_name"]
#confidence = res.body[0]["classifications"][0]["confidence"]
#extractions = SAM.extractors.extract(modelID, "Here i go yes")

#print(bodyData, "\n")
#print(f"Tag: {sentimentTag} | Confidence: {confidence}")



#graphing######################
plt.style.use("_classic_test_patch")
rawFile = "sample_data/hotelReviews.csv"
#hotelReviews = pd.read_csv(rawFile)
print("\n\n\n\n\n\n\n")

#iterate through texts to sentimentize:
#sentimentValues = SAM.classifiers.classify(modelID, list(hotelReviews.Text)).body

#print(sentimentValues)
rangeOf = 50
d = {
 #   "Review" : [hotelReviews.Text[a] for a in range(rangeOf)],
     'pseudo-sentimentsValue': [('%.2f' % random.random())  for a in range(rangeOf)]
    # "Sentiment": [str(x) for x in list(SAM.classifiers.classify(modelID, list(hotelReviews.Text)))]
}

newDF = pd.DataFrame(d)
newDF["pseudo-sentiment"] = [random.choice(["POSITIVE", "NEGATIVE"]) for a in range(rangeOf)]
#newDF["length"] = [len(hotelReviews.Text[a]) for a in range(rangeOf)]
#newDF["Review"]
#newDF.iloc[1]



#x = newDF.length
#y = newDF['pseudo-sentimentsValue']


#print(list(hotelReviews.Text))

#plt.scatter(x, y)
#plt.show()

#print(end = "\n\n")
#newDF

# %%
#USING TWITTER  = The twotter api used to to extract tweets, thats all, and view accounts 
print("available plt styles now: \n", plt.style.available, end = "\n\n")
plt.style.use("bmh")

#filesUploaded = files.upload()   #upload files through these code
#log = pd.read_csv("fileName.csv")

#trainingFile1 = pd.read_csv("sample_data/hotelReviews.csv")



#twitter api credentials 
consumerKey = ""
consumerSecret = ""
accessToken = ""
accessTokenSecret = ""


#authintication
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)

#api obj
api = tweepy.API(auth, wait_on_rate_limit=True)
#api.get_user()

# %%
#############################################################################################################SEPERATOR##################################################################################################################

# %%
def say(text):
  engine = pyttsx3.init()
  engine.say(text)
  engine.runAndWait()

#say("Hello Universe")


def textToSpeech(text):
  text = gTTS(text)
  text.save("currentTextToSpeech.wav")
  currentFile = "currentTextToSpeech.wav"
  return Audio(filename= currentFile, autoplay = True)
  
#text = gTTS("Hello, Esteban Cubides. Here")
#text.save("sample.wav")
#soundFile = "sample.wav"
#Audio(filename= soundFile, autoplay = True)

textToSpeech("Hello Universe")

# %%
#examplar of a character profile. 

def markTwainFunct(sentiment):
  if sentiment == "POSITIVE":
    return "I dont quite agree that humans are 100% or even 75% not dispicble. We have proven that fact wrong for the past hundreds of years, and we will keep on proving it wrong, it shows to be embeded in our dna."
  else:
    return "Exactly correct! Humans seem to be inately dispicable, so we must make efforts to supress those desires."
markTwain = {
    "argument": "There are multiple examples of humans performing unnecessary cruelty to each other among other immoral actions. One of many is a religious zealot skinning a fellow human’s backs and then pouring salt \non the open wound. Or even animals who have done nothing to the humans having to deal with their greed and desire for satisfaction, such as when hunters killed 72 buffalos to entertain an English earl, \nthen they partially ate one and left the other 71 bulls to rot. All these examples are meant to exemplify humans' selfishness in their path to desire, so when such a selfish animal decides to make a society, \nran by the same animal who rapes, kills, tortures, shames, and manipulates for their own gain, while knowing every step they took was immoral, what other outcome is to be expected except one where the same actions taken \nto build it are secretly promoted? ", 
    "function": markTwainFunct
}
class MarkTwain:
  def getArgument(self):
    return markTwain["argument"]
  def getResponse(self, sentiment):
    if sentiment == "POSITIVE":
      return "I dont quite agree that humans are 100% or even 75% not dispicble. We have proven that fact wrong for the past hundreds of years, and we will keep on proving it wrong, it shows to be embeded in our dna."
    else:
      return "Exactly correct! Humans seem to be inately dispicable, so we must make efforts to supress those desires."
MarkTwainInst1 = MarkTwain()






def adamSerwerFunct(sentiment):
  if sentiment == "POSITIVE":
    return "You see....... Trump is just an example of humans being dispicable, Trump infected others who became his supporters with the same dispicableness. It started to spread like a wave, people wanted to become part of something but where to latched on to the satisfaction of these acts and being part of something with energy. They embraced all the dispicable energy."
  else:
    return "Exactly, you perfectaly understand my point and the truth about the moden world and it's people in power."
adamSerwer = {
    "argument": "Everyone at one point has been cruel to another human and felt good about it, it is just human nature. Whether you were five years old and made fun of a classmate for their new glasses with your peers, or noticed a \nco-worker ignored you when you needed help so when he needs your help you ignore him back. Acts like that are “okay” although immature, but what happens when a world leader shows the same signs of \ncruelty as a five year old but on a larger scale?"
}
class AdamSerwer:
  def getArgument(self):
    return adamSerwer["argument"]
  def getResponse(self, sentiment):
    if sentiment == "POSITIVE":
      return "You see....... Trump is just an example of humans being dispicable, Trump infected others who became his supporters with the same dispicableness. It started to spread like a wave, people wanted to become part of something but where to latched on to the satisfaction of these acts and being part of something with energy. They embraced all the dispicable energy."
    else:
      return "Exactly, you perfectaly understand my point and the truth about the moden world and it's people in power."
AdamSerwerInst1 = AdamSerwer()





  
whiteyOnMoon = {
   "argument": "The taxes, rent, goods and all services are being used for the advtagae of the governmemnt at the expense of the people financial and overall well being. Im paying more and more for goods, evey time i go to shop \nfor them. The taxes increase yearly, rents and mortgages are increasing as well. A rat bit my sister and i dont have enough money to pay the medical bills, guess why? Thats right, where did all the money go? \nYet Whitey's on the moon",
   "counterArgument": " ",
   "claim": " "
}
class WhiteyOnMoon:
  def getArgument(self):
    return whiteyOnMoon["argument"]
  def getResponse(self, sentiment):
    if sentiment == "POSITIVE":
      return "Sadly , i have to disagree with you on the positive aspect. The govenrment thas proven me that once you have power at hands, the dark side of humanity is revelaved and embraced by the individual. \nWhile there are many African Americans and low status Americans, Americans without such power or influence, enough to be heard and have an impact, without resources to even live half of what is considered \na fair and humane life. Yet Whitey is still on the moon."
    else:
      return "Exactly, you perfectaly understand my point and the truth about the moden world and it's people in power. YES!"
WhiteyOnMoonInst1 = WhiteyOnMoon()




drKing = {
    "argument": "Humans are not dispicable, even though sometimes we may commit dispicable acts, that does not define us entirely as dispacble. At our core we love, care and have the desire to do good in this world.",
    "counterArgument": f"As the reason for my letter to the chlergy mens was to defend myself and justify the reason why  i am not an outsider,\n and there for i should have a say. The chlergy mens disagreed before and some even after, only because i was of a different color. \nBut most importantly, i wrote this letter to open their eyes and retrieve their miss-understood belief and replace it with the rightious type of mindset.",
    "claim": "These white chlergy mens are part of group(s) that apply preassure through expectations from every individual and chief. So it is understandabe that although some may agree with me, they fear their group more than the tryth. I call this peer-preassure."
}
class DrKing:
  def getArgument(self):
    return drKing["argument"]
  def getResponse(self, sentiment):
    if sentiment == "POSITIVE":
      return "Yes, even though thosse clergy men were very disrespecful to me, even though they had absolutky no right to do what they did, and try to silence me as an outsider. It was very dispicable of them to make up laws and rules like such, that dont apply to them. I was born here, they were born here so if im considered and outsider, why cant them?  \nBut I also have no right to act the same way as them or else i will be just as blamable. But everyone can be given a second chance."
    else:
      return "Perhaps humans are very cruel, but we can change. There many negatives about us but the positives has to also be considered. We can change and control this dispicable gene."
DrKingInstance1 = DrKing()

authors = [None, MarkTwainInst1, AdamSerwerInst1, WhiteyOnMoonInst1, DrKingInstance1]

#textToSpeech(markTwain.get("argument"))
#print(markTwain.get("argument"))
#print(authors[1]["argument"])

# %%
#name of model: SAM - Sentiment Analysis Model
apiKey2 = "143f8b8661006e7a1cd0c8f6a0846e80c9a05f07"
modelID2 = "cl_cquebFxh"


apiKey = "13395cd5bcc1f17e700a070b4db987fa846863ba"
modelID = "cl_dbjkVcub"

def getSentiment(text):
  SAM = MonkeyLearn(apiKey2)
  textSentiment = SAM.classifiers.classify(modelID2, ["Humans are super good and nice"])
  return textSentiment.body[0]["classifications"][0]["tag_name"]

#print(getSentiment(["Humans are bad"]))

def startSimulation():
  running = True
  while running:
    userDesire = input("Continue simulation? ").upper()
    if userDesire == "YES":
      print("""
      Author id: 
      1 = Mark Twain, 2 = Adam Serwer,
      3 = Whitey On the Moon, 4 = Dr. King 
      """)
      userPick = int(input("Enter number for corresponding author: "))
      print(authors[userPick].getArgument(), end = "\n")
      userOpinion = input("Enter opinion: ")
      sentimentGotten = getSentiment(userOpinion).upper()
      print(sentimentGotten)
      print(authors[userPick].getResponse(sentimentGotten))
      continue
    else:
      print("Okey, have a great day!")
      break

# %%
startSimulation()

# %% [markdown]
# Essay:
# By: Anderson Blanco, Esteban Cubudes
#
# Humans are dispicable in many ways, but not for the most part.Those who avoid showing this dispicable behavior; are larger in population, while the ones who decided to embrace, are less. Among those who decide not to embrace it, there are those who fight back, not letting these despicable acts over power them, run, and judge their lives. Truth is, dispicable events can happen, unless not given the oppourtunity to. Acts like these are oopportunistic.
#
# There are 4 articles("The Lowest Animal" by Mark Twain, "The curelty is in the point" by Adam Serwer, Dr.King's letter to the clurgy men in "Modern Applications of Ancient Rhetoric", and "Whitey on The Moon") proving these two claims; humans have dispicable nature, but can be controled and avoided. Dispicable acts can be avoided and stoped from happening, we can defend ourselves from it.
#
# /////////////// 1 paragraph, for each article, providing explanation and proof to support the claim////////////////////////////////////////////////////////////
#
#
#
#
#
#
#
# Apart from the above articles, i have some experiences that can prove the claims. A bit of my past; i was born in Dominican Republic, which is a 3rd wolrd country. With taht said, you can imagine that there are lots of corruption and it's simply not a healthy place to grow up in. Most of it's areas are governed by dispicable people, but the government is the main body responsible for the crimes currently active today. The whole populuation has been under emergency ever since

# %%
////////////////////////////////////////////////////////////////////////////////////////////

# %% [markdown]
# "Thew Lowest Animal" by Mark Twain
#
#   Humans are aperantly at the top of the food chain, and are considered the higher animals. The reason for this is thanks to our Moral sense(ability to distinguish good from bad). Yet this same moral sense has made us dispicable beings, incapable of inosence, at times. We voluntarily commit evil acts, knowing these will have destructive effects. On page 2, Mark Twain demonstrates a comparison between cats and humans. Cats are innocent and when the do wrong , they are not aware of it due to their lack of moral sense, which saves them or makes them unguilty. On the other hand, man is concious. Man is not innocent, because of the moral sense man is aware of his actions, and when commiting dispicable acts; man finds pleasure in this, making man not innocent. As Mark Twain expresses on page 1, man always wants more and more. The more man has the more he wants and the worst the acts will become, feeding the greed. Man will even go so far to harm his own moral kind, being inconsiderate of the values that we share. In contrast to animals in the wild, they dont "accumulates" food but rather eat and leave what is left over. Man "accumulates" what he needs and dosnt need, with what seems no limit. (page 4) Instead of the highest animal, humans should be the "lowest". After each that we do, we keep finding more and more pleasure to fuel our greed to redo these acts, as it it wasnt enough.
#
#
#
#   "The cruelty is the point" by Adam Serwer
#
#  Even with today's modern civilization, advanced politics and other fields, the time when humans should be getting along the most is today (according to past predicitons of the future). Yet it is the opposite, they say that the most powerful should protect the least powerful(storng protect the weak), but today the most powerful takes advantage of the poor and the poeple who have little to no say because of the enourmous influence that the people in power have. On page 3, Donald J Trump is used as an example of curelty. Trump's administration was searching to cleanse mnore than 193,000 American imigrant children, after those children's protection status was nulified by the same administartion. Trump's administartion wasnt only seeking to export illegal imigrants from US, but he was alos seeking to curely setup up those who had legal protetcion to fail and be exported as well. This by it's own is a very cruel act, showing hatred towarsd innocent people who had temporary legal protected status. On teh same page, and page 5; Trump ridiculed a psychology professor, Christine Blasely Ford, who claims that life-time nominated Supreme Court, Brett Kavanaugh, has attempted to rape her as a teenager. In a live public Mississippi rally, Trump's supporters supported Trump's cruel act, and shouted "Lock her up!", cheering Trump on. There was also cruelty at the USA borders, with patrol agents laughing at the crying imigrant children who were seperated from their families. Among the other many thse are some inyteresting occurance;  police laughed upon being encouraged to abuse suspects by Trump, Fox News hosts mocked survivor of Pulse Nightclub. Trump not only gets satisfaction from doing these types of acts, but he also enjoys encouraging others to do the same, and others follow up into the cruelty, turning everyone into a mentaly cruel America, something they werent before. This dispicable wave overflows through Trump and his supporters, showing the true nature embraced and re-enforced by them.
#
#
# "WHitey On The Moon"
#
#   There many things to be achivied with every new technology humans invent or discover. But are these technologies and knew resources worth betraying your other fellow human beings? As a person in power, responsible for the well-being of your citizens, do personal interest, or any other interest other than the well-being of your fellow humans, out weight the well-being and the general value of humans? Come to think about it, without the well-being of humans, there cant be any progress done outside of the necesities of each individual. If an individual does not meet it's necesities, they are not efficient and the same follows up for upcoming generations. Unfourtunatetly, the govenrment prefers other objectives over human values, they prefer to send a man to the moon at the cost of innocent American peace and well being.(Verse 1) The author starts with a special harmful event that happened to his sister, as her face and arms bulged up, yet "and whitey's on the moon".(Verse 2 and 3) The author's rent increased, there was no water and toilets nor lights, and there were doctor bill sto be paid for his sister's inury. The living standards of the author, and others like him, didnt meet the minimal standards and health support could not be afforded, but there is still a man on the moon. With each  verse including "whitey's on the moon"; no matter the maginitude of the occurances in the verse, there is a man on the moon sent by using the money that belongs to the American's like the author.(Verse 6) No matter the amnount of money made, it went all to the govenrmenmt through taxes and overpriced goods and services, all to send a man to the moon. It is hard enough to survive as a low living standard person, and cruel for the one system that is supposed to protect the rights and well being of citizens, to overcharge services and goods, increase taxes, to then collect the money needed to send a man to the moon. The moon resources can wait, they will not disapear, but humans have a life span which shortens when they are not in well enough confitions. Large amounts of money is needed to sned a man to the moon. The money used for that could've been used on the basic needs of Americans, in turn these Americans will be more efficient at their roles and works, making more money and discoveries. But after you spend money on the moon, it is highly probable you will get little to no money back, no matter the amount.

# %% [markdown]
# Marther Luther King's letter to the CLurgy Men.
#
#    Though humans can be very dispicable, it can be understood that perhaps those who are, in fact just misunderstand the proper way to think about others. People who embrace the dispicableness might not truly be doing it with super bad intentions based on hatred and satisfaction, but based on a wrongful belief and the peer preasure from the surrounding people in their clan or group. The peer preasure forces the supporters of the group to do certain things in order to fit in and not lose their community support and love. Some bible texts might also be mis-interpreted, like in the bible (Verse1 Peter 2:18); "Servants, be subject to your masters with all fear." humans can misundertand it as to enslave those who are less than them, because humans are selfish and believe that they are better than others that are different. Pages # through #, Dr.King's letter is introduced. Dr.King starts his letter with a nice peaceful introduction "Hello my fellow CLergy men", followed by the introduction to the main problem. The clergy men claimed that Dr.King is an outsider, yet he was born in the US. While Dr.King defends himself inteligently and peacefully without brining himself down to the their level, claiming he is not an outsider. On page # ----------//talk about the text evidence, restating it-------------
# Just like Dr.Kign there are many who have tried and those who are trying to fix the misunderstood idea of doing the wrong thing, but there are those who try to divereg the good deeds and the good intentions of others, dragging them into a false sense of reality and decission making, all because they want to be part of something and desire to be included.
